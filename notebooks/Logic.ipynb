# %% [markdown]
# # CreditWise Loan Approval System

# %% [markdown]
# ## 1. Importing Libraries

# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

# %%
from src.preprocessing import preprocess_data, encoding,feature_sq
from src.eda import pie_chart, bar_graph
from src.train import lr,nb,knn,evaluate_model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# ## 2. Loading Data

# %%
cleaned_data = preprocess_data("../Data/loan_approval_data.csv")
cleaned_data.head(5)
# Out:
#    Applicant_ID  Applicant_Income  Coapplicant_Income Employment_Status   Age  \
# 0           1.0           17795.0              1387.0          Salaried  51.0
# 1           2.0            2860.0              2679.0          Salaried  46.0
# 2           3.0            7390.0              2106.0          Salaried  25.0
# 3           4.0           13964.0              8173.0          Salaried  40.0
# 4           5.0           13284.0              4223.0     Self-employed  31.0
#
#   Marital_Status Dependents  Credit_Score  Existing_Loans  DTI_Ratio  Savings  \
# 0        Married        0.0         637.0             4.0       0.53  19403.0
# 1        Married        3.0         621.0             2.0       0.30   2580.0
# 2         Single        2.0         674.0             4.0       0.20  13844.0
# 3        Married        2.0         579.0             3.0       0.31   9553.0
# 4         Single        2.0         721.0             1.0       0.29   9386.0
#
#    Collateral_Value  Loan_Amount  Loan_Term Loan_Purpose Property_Area  \
# 0           45638.0      16619.0       84.0     Personal         Urban
# 1           49272.0      38687.0       48.0          Car     Semiurban
# 2            6908.0      27943.0       72.0     Business         Urban
# 3           10844.0      27819.0       60.0     Business         Rural
# 4           37629.0      12741.0       72.0          Car         Urban
#
#   Education_Level  Gender Employer_Category Loan_Approved
# 0    Not Graduate  Female           Private            No
# 1        Graduate    Male           Private            No
# 2        Graduate  Female        Government           Yes
# 3        Graduate  Female        Government            No
# 4        Graduate    Male           Private           Yes

# %% [markdown]
# ## 4. Exploratory Data Analysis (EDA)

# %%
pie_chart(cleaned_data,"Loan_Approved", ["Yes","No"],"Is Loan approved or not?")

# %%
bar_graph(cleaned_data,"Education_Level")

# %%
# analyze income
sns.histplot(
    data = cleaned_data,
    x = "Applicant_Income",
    bins=20
)
# Out:
# <Axes: xlabel='Applicant_Income', ylabel='Count'>

# %%
sns.histplot(
    data = cleaned_data,
    x = "Coapplicant_Income",
    bins=20
)
# Out:
# <Axes: xlabel='Coapplicant_Income', ylabel='Count'>

# %%
# outliers - box plots
fig, axes = plt.subplots(2, 2)

sns.boxplot(ax=axes[0, 0], data=cleaned_data, x="Loan_Approved",y="Applicant_Income")
sns.boxplot(ax=axes[0, 1], data=cleaned_data, x="Loan_Approved",y="Credit_Score")
sns.boxplot(ax=axes[1, 0], data=cleaned_data, x="Loan_Approved",y="DTI_Ratio")
sns.boxplot(ax=axes[1, 1], data=cleaned_data, x="Loan_Approved",y="Savings")

plt.tight_layout()

# %%
# Credit Score with Loan Approved
sns.histplot(
    data=cleaned_data,
    x="Credit_Score",
    hue="Loan_Approved",
    bins=20,
    multiple="dodge"
)
# Out:
# <Axes: xlabel='Credit_Score', ylabel='Count'>

# %%
sns.histplot(
    data=cleaned_data,
    x="Applicant_Income",
    hue="Loan_Approved",
    bins=20,
    multiple="dodge"
)
# Out:
# <Axes: xlabel='Applicant_Income', ylabel='Count'>

# %% [markdown]
# ## 5. Encoding

# %%
data = encoding(cleaned_data)

# %%
num_cols = data.select_dtypes(include="number")
corr_matrix = num_cols.corr()

plt.figure(figsize=(15, 8))
sns.heatmap(
    corr_matrix,
    annot=True,
    fmt=".2f",
    cmap="coolwarm"
)
num_cols.corr()["Loan_Approved"].sort_values(ascending=False)
# Out:
# Loan_Approved                      1.000000
# Credit_Score                       0.476980
# Applicant_Income                   0.126248
# Employer_Category_MNC              0.073448
# Marital_Status_Single              0.037586
# Loan_Purpose_Personal              0.035519
# Collateral_Value                   0.027248
# Property_Area_Urban                0.025731
# Coapplicant_Income                 0.009077
# Applicant_ID                       0.003134
# Loan_Purpose_Home                  0.003108
# Employer_Category_Private          0.000707
# Employment_Status_Self-employed   -0.003042
# Loan_Purpose_Education            -0.011940
# Property_Area_Semiurban           -0.014259
# Savings                           -0.016878
# Age                               -0.027362
# Employer_Category_Unemployed      -0.028736
# Existing_Loans                    -0.035753
# Employment_Status_Salaried        -0.038259
# Employer_Category_Government      -0.039135
# Gender_Male                       -0.048998
# Employment_Status_Unemployed      -0.053860
# Education_Level                   -0.056283
# Loan_Purpose_Car                  -0.063428
# Loan_Term                         -0.089884
# Loan_Amount                       -0.127399
# DTI_Ratio                         -0.460487
# Name: Loan_Approved, dtype: float64

# %% [markdown]
# ## 6. Feature Engineering & Train-Test Split

# %%
# Add or Tranform features
feature_sq(data,"DTI_Ratio_sq","DTI_Ratio")
feature_sq(data,"Credit_Score_sq","Credit_Score")


# df["Applicant_Income_log"] = np.log1p(df["Applicant_Income"])

X = data.drop(columns=["Loan_Approved", "Credit_Score", "DTI_Ratio","Applicant_ID"])
y = data["Loan_Approved"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# ## 7. Model Building

# %%
lr = lr()
lr.fit(X_train, y_train)
nb = nb()
nb.fit(X_train, y_train)
knn = knn()
knn.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('knn', KNeighborsClassifier())]),
#              param_grid={'knn__n_neighbors': [3, 5, 7, 9]},
#              scoring='precision')

# %%
y_pred_lr = lr.predict(X_test)
y_pred_nb =nb.predict(X_test)
y_pred_knn = knn.predict(X_test)

# %% [markdown]
# ## 8. Evaluation

# %%
evaluate_model("LR", y_test, y_pred_lr)
evaluate_model("NB", y_test, y_pred_nb)
evaluate_model("KNN", y_test, y_pred_knn)
# Out:
# LR
# Accuracy Score LR: 0.8471337579617835
# Precision Score LR: 0.9152542372881356
# Recall Score LR: 0.5567010309278351
# F1 Score LR: 0.6923076923076923
# --------------------------------------------------
# NB
# Accuracy Score NB: 0.8821656050955414
# Precision Score NB: 0.8409090909090909
# Recall Score NB: 0.7628865979381443
# F1 Score NB: 0.8
# --------------------------------------------------
# KNN
# Accuracy Score KNN: 0.7834394904458599
# Precision Score KNN: 0.7101449275362319
# Recall Score KNN: 0.5051546391752577
# F1 Score KNN: 0.5903614457831325
# --------------------------------------------------

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

for ax, y_pred, title in zip(axes, 
                              [y_pred_lr, y_pred_nb, y_pred_knn], 
                              ["Logistic Regression", "Naive Bayes", "KNN"]):
    cm = confusion_matrix(y_test, y_pred)
    ConfusionMatrixDisplay(cm).plot(ax=ax)
    ax.set_title(title)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 9. Conclusion

# %% [raw]
# Among the three models evaluated, Naive Bayes performs best overall for this loan approval task.
#
# While Logistic Regression achieves the highest precision (0.915), its recall is very low (0.557),
# meaning it rejects a large number of genuinely eligible applicants — directly causing the
# "good customers get rejected" problem stated in the problem statement.
#
# Naive Bayes strikes the best balance with an accuracy of 88.2%, precision of 0.841,
# recall of 0.763, and the highest F1 score of 0.800 — making it the most reliable model
# for this use case.
#
# KNN underperforms on all metrics and is not suitable here.
#
# For a production loan system, Naive Bayes would be the recommended model, with recall
# being the priority metric since missing a creditworthy applicant is costly to the business.
